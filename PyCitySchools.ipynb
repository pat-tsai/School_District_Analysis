# %%
# adding pandas dependency
import pandas as pd

# %%
# Files to load
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
# loading dfs
school_data_df = pd.read_csv(school_data_to_load)
school_data_df.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
student_data_df = pd.read_csv(student_data_to_load)
student_data_df.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# cleaning the data
school_data_df.count()
student_data_df.count()
# Out:
# Student ID       39170
# student_name     39170
# gender           39170
# grade            39170
# school_name      39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# chaining functions to find null values
school_data_df.isnull().sum()
# Out:
# School ID      0
# school_name    0
# type           0
# size           0
# budget         0
# dtype: int64

# %%
student_data_df.isnull().sum()
# Out:
# Student ID       0
# student_name     0
# gender           0
# grade            0
# school_name      0
# reading_score    0
# math_score       0
# dtype: int64

# %%
student_names = student_data_df['student_name'].tolist()

# %%
faulty_names = []

for name in student_names:
 #   print(name.split(), len(name.split()))
    if len(name.split()) >= 3:
        faulty_names.append(name)

faulty_names
# Out:
# ['Dr. Richard Scott',
#  'Dr. Jordan Carson',
#  'Madeline Snyder MD',
#  'Mr. Dylan Taylor MD',
#  'Dr. Scott Gill',
#  'Miss Madison Everett',
#  'Virginia Ramirez MD',
#  'Joseph Morales III',
#  'Angela Perkins DVM',
#  'Heather Allen MD',
#  'Luke Lowery MD',
#  'Dr. Larry Hines',
#  'Emily Cardenas MD',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Mrs. Lisa Becker',
#  'Mr. Travis Young',
#  'Paula Fernandez DVM',
#  'Dr. Xavier Bell II',
#  'Andrew Hanson MD',
#  'Mr. Roberto Wright MD',
#  'Mr. Dale Miller',
#  'Mary Gonzalez DDS',
#  'Mrs. Cindy Brown',
#  'James White MD',
#  'Donald Gill DDS',
#  'Mrs. Catherine Williams MD',
#  'Ashley Caldwell MD',
#  'Mr. Jared Campbell',
#  'Michael Moreno PhD',
#  'Tara Parker MD',
#  'Shawn Williams DVM',
#  'Dr. Alicia Martinez',
#  'Mr. Timothy Anderson',
#  'Mrs. Paula Lee',
#  'Mr. Elijah Hall',
#  'Mr. Raymond Stone',
#  'John Dickerson MD',
#  'Mr. Alex Franklin',
#  'Mrs. Jessica Dunn',
#  'Mr. Michael Stevenson',
# ...

# %%
len(faulty_names)
# Out:
# 1531

# %%
prefixes, suffixes = [], []

for name in faulty_names: 
    if len(name.split()[0]) <= 4:
        prefixes.append(name.split()[0])
    elif len(name.split()[-1]) <= 3:
        suffixes.append(name.split()[-1])

# %%
prefixes
# Out:
# ['Dr.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Miss',
#  'Luke',
#  'Dr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mary',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'John',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Dale',
#  'Dr.',
#  'Dr.',
#  'Dr.',
#  'Ms.',
#  'Dr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Amy',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Lisa',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mark',
#  'Mrs.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Cody',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Ms.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Sara',
#  'Mr.',
#  'Mrs.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
# ...

# %%
fixes_made = len(prefixes) + len(suffixes)

# %%
len(faulty_names)
# Out:
# 1531

# %%
# returns unique values stored within list
set(suffixes)
# Out:
# {'DDS', 'DVM', 'II', 'III', 'IV', 'Jr.', 'MD', 'PhD'}

# %%
student_data_df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
# replacing prefixes/suffixes: .strip() will replace any character(s) that are within parenthesis, whereas .replace() will match exact cases
cleaned_prefixes_suffixes = ['Dr. ', 'Miss ', 'Mrs. ','Ms. ','Mr. ', ' DDS', ' DVM', ' MD', ' PhD']
#cleaned_faulty_list = []
#for name in faulty_names:
#    for prefix in cleaned_prefixes:
#            if prefix == name.split()[0]:
#                cleaned_faulty_list.append(name.replace(prefix, ""))
#    if name.split()[-1] in suffixes:
#        cleaned_faulty_list.append(name.replace(name.split()[-1],""))
for prefix in cleaned_prefixes_suffixes:
    student_data_df['student_name'] = student_data_df['student_name'].str.replace(prefix, "")

stu_names = student_data_df['student_name'].tolist()

student_names_fixed = []

for name in stu_names:
    if len(name.split()) >= 3:
        student_names_fixed.append(name)
len(student_names_fixed)
# Out:
# 151

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
student_data_df.to_csv('cleaned_student_data.csv', index=False)

# %%
school_data_df.columns
# Out:
# Index(['School ID', 'school_name', 'type', 'size', 'budget'], dtype='object')

# %%
student_data_df.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
school_data_complete_df = pd.merge(student_data_df, school_data_df, on=['school_name', 'school_name'])
school_data_complete_df.head()
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School             66
# 1           1     Victor Smith      M  12th  Huang High School             94
# 2           2  Kevin Rodriguez      M  12th  Huang High School             90
# 3           3    Richard Scott      M  12th  Huang High School             67
# 4           4       Bonnie Ray      F   9th  Huang High School             97
#
#    math_score  School ID      type  size   budget
# 0          79          0  District  2917  1910635
# 1          61          0  District  2917  1910635
# 2          60          0  District  2917  1910635
# 3          58          0  District  2917  1910635
# 4          84          0  District  2917  1910635

# %%
# finding total number of students
student_count = school_data_complete_df['Student ID'].count()
student_count
# Out:
# 39170

# %%
school_count = school_data_df['school_name'].count()
school_count
# Out:
# 15

# %%
# creates a list of all unique values
schoolCount = school_data_complete_df['school_name'].unique()
len(schoolCount)
# Out:
# 15

# %%
total_budget = school_data_df['budget'].sum()
total_budget
# Out:
# 24649428

# %%
average_reading_score = school_data_complete_df['reading_score'].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
average_math_score = school_data_complete_df['math_score'].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
passing_math = school_data_complete_df[school_data_complete_df['math_score'] >= 70]
passing_math.head()
# Out:
#    Student ID   student_name gender grade        school_name  reading_score  \
# 0           0   Paul Bradley      M   9th  Huang High School             66
# 4           4     Bonnie Ray      F   9th  Huang High School             97
# 5           5  Bryan Miranda      M   9th  Huang High School             94
# 6           6  Sheena Carter      F  11th  Huang High School             82
# 8           8   Michael Roth      M  10th  Huang High School             95
#
#    math_score  School ID      type  size   budget
# 0          79          0  District  2917  1910635
# 4          84          0  District  2917  1910635
# 5          94          0  District  2917  1910635
# 6          80          0  District  2917  1910635
# 8          87          0  District  2917  1910635

# %%
passing_reading = school_data_complete_df[school_data_complete_df['reading_score'] >= 70]
passing_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1                 94          61          0  District  2917  1910635
# ...

# %%
passing_math_count = passing_math['student_name'].count()
passing_reading_count = passing_reading['student_name'].count()

passing_math_percentage = passing_math_count / student_count * 100
passing_reading_percentage = passing_reading_count / student_count * 100

# %%
print(passing_math_count)
print(passing_reading_count)
print(student_count)
# Out:
# 29370
# 33610
# 39170

# %%
passing_math_reading = school_data_complete_df[(school_data_complete_df['math_score'] >= 70) & (school_data_complete_df['reading_score'] >= 70)]
passing_math_reading
# Out:
#        Student ID     student_name gender grade         school_name  \
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# 9               9   Matthew Greene      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 4                 97          84          0  District  2917  1910635
# ...

# %%
overall_passing_percentage = 100 * passing_math_reading['student_name'].count()/student_count
overall_passing_percentage
# Out:
# 65.17232575950983

# %%
# Adding a list of values with keys to create a new DataFrame.
district_summary_df = pd.DataFrame(
          [{"Total Schools": school_count,
          "Total Students": student_count,
          "Total Budget": total_budget,
          "Average Math Score": average_math_score,
          "Average Reading Score": average_reading_score,
          "% Passing Math": passing_math_percentage,
         "% Passing Reading": passing_reading_percentage,
        "% Overall Passing": overall_passing_percentage}])
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
# formatting
district_summary_df['Total Students'] = district_summary_df['Total Students'].map("{:,}".format)

# %%
district_summary_df
# Out:
#    Total Schools Total Students  Total Budget  Average Math Score  \
# 0             15         39,170      24649428           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
district_summary_df['Total Budget'] = district_summary_df['Total Budget'].map("${:,.2f}".format)

# %%
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0               81.87784       74.980853          85.805463          65.172326

# %%
#district_summary_df['Average Math Score'] = district_summary_df["Average Math Score"].map("{:.2f}".format)
#district_summary_df['% Passing Math'] = district_summary_df['% Passing Math'].map("{:.2f}%".format)

# %%
# Format the columns.
district_summary_df["Average Math Score"] = district_summary_df["Average Math Score"].map("{:.1f}".format)

district_summary_df["Average Reading Score"] = district_summary_df["Average Reading Score"].map("{:.1f}".format)

district_summary_df["% Passing Math"] = district_summary_df["% Passing Math"].map("{:.0f}".format)

district_summary_df["% Passing Reading"] = district_summary_df["% Passing Reading"].map("{:.0f}".format)

district_summary_df["% Overall Passing"] = district_summary_df["% Overall Passing"].map("{:.0f}".format)

# %%
district_summary_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00               79.0
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.9             75                86                65
